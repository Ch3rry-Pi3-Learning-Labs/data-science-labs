# %% [markdown]
# # <font color="#4DAAFC"><strong>[Learning Lab title]</strong></font>
#
# **CH3RRY PI3 Data Science Learning Labs**
#
# [One friendly paragraph explaining the problem, why it matters and what the reader will build. Follow it with a short roadmap explaining the order of the notebook.]
#
# **Intended audience:** [Audience]
# **Prerequisites:** [Prerequisites]
# **Estimated study time:** [Time]
# **Last reviewed:** [Date]

# %% [markdown]
# ## <font color="#4DAAFC"><strong>Learning journey</strong></font>
#
# Use this roadmap to show the reader how the notebook develops. Keep each stage short, link it to the relevant section and make the dependency between stages visible.
#
# **[Frame the problem](#problem)** &rarr; **[Establish the mathematics](#mathematics)** &rarr; **[Build the method](#method)** &rarr; **[Assemble the implementation](#complete-implementation)** &rarr; **[Interpret the result](#visualise)** &rarr; **[Validate and reflect](#checks)**
#
# <table>
# <thead><tr><th align="left"><font size="4">Stage</font></th><th align="left"><font size="4">Purpose</font></th><th align="left"><font size="4">Main section</font></th></tr></thead>
# <tbody>
# <tr><td align="left"><font size="4">1. Frame</font></td><td align="left"><font size="4">Define the question and why it matters.</font></td><td align="left"><font size="4"><a href="#problem">Section 2</a></font></td></tr>
# <tr><td align="left"><font size="4">2. Formalise</font></td><td align="left"><font size="4">Introduce and explain the required mathematics.</font></td><td align="left"><font size="4"><a href="#mathematics">Section 3</a></font></td></tr>
# <tr><td align="left"><font size="4">3. Build</font></td><td align="left"><font size="4">Develop and test each calculation separately.</font></td><td align="left"><font size="4"><a href="#method">Sections 4–5</a></font></td></tr>
# <tr><td align="left"><font size="4">4. Assemble</font></td><td align="left"><font size="4">Combine the verified pieces into the complete method.</font></td><td align="left"><font size="4"><a href="#complete-implementation">Section 6</a></font></td></tr>
# <tr><td align="left"><font size="4">5. Interpret</font></td><td align="left"><font size="4">Visualise the output and explain what it means.</font></td><td align="left"><font size="4"><a href="#visualise">Section 7</a></font></td></tr>
# <tr><td align="left"><font size="4">6. Validate</font></td><td align="left"><font size="4">Check behaviour, state limitations and consolidate the lesson.</font></td><td align="left"><font size="4"><a href="#checks">Sections 8–9</a></font></td></tr>
# </tbody>
# </table>

# %% [markdown]
# ## <font color="#4DAAFC"><strong>Learning objectives</strong></font>
#
# By the end of this Learning Lab, you should be able to:
#
# 1. [Explain a central idea.]
# 2. [Perform or derive an important calculation.]
# 3. [Implement the method in Python.]
# 4. [Interpret its output and recognise an important limitation.]

# %% [markdown]
# ## <font color="#4DAAFC"><strong>Contents</strong></font>
#
# 1. [Imports and reproducibility](#imports)
# 2. [Problem and intuition](#problem)
# 3. [Mathematical foundations](#mathematics)
# 4. [Build the method one step at a time](#method)
#    - [Focused calculation](#focused-calculation)
#    - [Read the output](#read-output)
# 5. [Hand-worked example](#worked-example)
# 6. [Assemble the complete implementation](#complete-implementation)
# 7. [Visualise and interpret the result](#visualise)
# 8. [Sanity checks and limitations](#checks)
# 9. [Summary and next steps](#summary)

# %% [markdown]
# <a id="imports"></a>
# ## <font color="#4DAAFC"><strong>1. Imports and reproducibility</strong></font>
#
# Explain what each dependency contributes and distinguish supporting setup from the method itself.

# %%
# Standard imports and reproducibility
from __future__ import annotations

import numpy as np
import matplotlib.pyplot as plt

SEED = 5901
rng = np.random.default_rng(SEED)

SINGLE_PLOT_FIGSIZE = (12, 5.5)
TWO_PANEL_FIGSIZE = (12, 4.5)

# %% [markdown]
# <a id="problem"></a>
# ## <font color="#4DAAFC"><strong>2. Problem and intuition</strong></font>
#
# Begin with a section preview: why this section is needed, what it will establish and how that output will support the next stage. Then introduce the practical question, what is known, what must be learned and why the proposed method helps.

# %% [markdown]
# <a id="mathematics"></a>
# ## <font color="#4DAAFC"><strong>3. Mathematical foundations</strong></font>
#
# Define every symbol before using it. For example, let $N$ be the number of observations and let $\boldsymbol{\theta}\in\mathbb{R}^d$ be a parameter vector with $d$ elements.
#
# Introduce an important relationship using local section-based numbering:
#
# <a id="equation-3-1"></a>
# $$
# \large
# J(\boldsymbol{\theta})
# =\frac{1}{N}\sum_{i=1}^{N}\ell_i(\boldsymbol{\theta}). \tag{3.1}
# $$
#
# [Equation (3.1)](#equation-3-1) can be read as: average the observation-level loss $\ell_i$ over all $N$ observations to obtain the overall objective $J$.

# %% [markdown]
# <a id="method"></a>
# ## <font color="#4DAAFC"><strong>4. Build the method one step at a time</strong></font>
#
# Explain why the first calculation is needed and how it connects to equation (3.1).

# %% [markdown]
# <a id="focused-calculation"></a>
# ### <font color="#4DAAFC"><strong>4.1 Focused calculation</strong></font>
#
# Describe the function's input, output and mathematical responsibility before defining it.

# %%
def focused_calculation(values: np.ndarray) -> float:
    """Return a clearly defined quantity from a one-dimensional array.

    Parameters
    ----------
    values
        Finite numerical values with shape ``(N,)``.

    Returns
    -------
    float
        Arithmetic mean of the supplied values.

    Raises
    ------
    ValueError
        If ``values`` is empty, non-dimensional or non-finite.
    """
    values = np.asarray(values, dtype=float)
    if values.ndim != 1 or values.size == 0:
        raise ValueError("values must be a non-empty one-dimensional array")
    if not np.all(np.isfinite(values)):
        raise ValueError("values must be finite")
    return float(values.mean())

# %%
demonstration_values = np.array([1.0, 2.0, 3.0])
demonstration_result = focused_calculation(demonstration_values)
print(f"Demonstration result: {demonstration_result:.2f}")

# %% [markdown]
# <a id="read-output"></a>
# ### <font color="#4DAAFC"><strong>4.2 Read the output</strong></font>
#
# Explain what the displayed value confirms, how it was obtained and how it will be used next.

# %% [markdown]
# <a id="worked-example"></a>
# ## <font color="#4DAAFC"><strong>5. Hand-worked example</strong></font>
#
# Explain why the example is included. Identify and link the earlier equation, restate its generic form, state the supplied values, show the substitution and important arithmetic, and interpret the result.

# %% [markdown]
# <a id="complete-implementation"></a>
# ## <font color="#4DAAFC"><strong>6. Assemble the complete implementation</strong></font>
#
# Combine the focused functions already developed. Do not replace them with an unrelated implementation.

# %% [markdown]
# <a id="visualise"></a>
# ## <font color="#4DAAFC"><strong>7. Visualise and interpret the result</strong></font>
#
# State what the plot will reveal before creating it, then explain the observed pattern afterwards.

# %% [markdown]
# <a id="checks"></a>
# ## <font color="#4DAAFC"><strong>8. Sanity checks and limitations</strong></font>
#
# Test invariants, edge cases and expected behaviour. State what the example does not establish.

# %% [markdown]
# <a id="summary"></a>
# ## <font color="#4DAAFC"><strong>9. Summary and next steps</strong></font>
#
# Revisit the learning journey, collect and link the principal equations, explain how they combine into the implementation, distinguish demonstrated results from limitations and suggest purposeful extensions.
